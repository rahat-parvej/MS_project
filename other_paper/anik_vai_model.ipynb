# %%
from tensorflow.keras.models import load_model

# %%
model=load_model("model/t_15_sec_gamma.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 3838, 5)           335
#
#  batch_normalization (Batch  (None, 3838, 5)           20
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 3838, 5)           0
#
#  max_pooling1d (MaxPooling1  (None, 1919, 5)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 1917, 5)           80
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 1917, 5)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 958, 5)            0
#  g1D)
#
#  dropout (Dropout)           (None, 958, 5)            0
#
#  conv1d_2 (Conv1D)           (None, 956, 5)            80
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 956, 5)            0
#
#  average_pooling1d (Average  (None, 478, 5)            0
#  Pooling1D)
#
#  dropout_1 (Dropout)         (None, 478, 5)            0
#
#  conv1d_3 (Conv1D)           (None, 476, 5)            80
#
# ...

# %%
model.get_weights()
# Out:
# [array([[[ 0.40778074,  0.00781436, -0.22253458,  0.1763995 ,
#            0.03435288],
#          [ 0.23375213, -0.0698527 ,  0.0531952 ,  0.14321716,
#           -0.17587098],
#          [ 0.0786557 , -0.05597894,  0.18666239, -0.06830261,
#           -0.04481793],
#          [-0.02379236,  0.25282046,  0.1996963 ,  0.07081617,
#           -0.07742132],
#          [ 0.26336187,  0.01322906,  0.16511807,  0.00933154,
#           -0.4079307 ],
#          [ 0.21230915, -0.25361285,  0.04643911,  0.19247894,
#            0.08613922],
#          [-0.01855083,  0.3136788 , -0.11512468,  0.06370518,
#           -0.1286156 ],
#          [-0.24415486,  0.15190543,  0.1509532 ,  0.23921889,
#            0.05491886],
#          [ 0.12643321,  0.22458118,  0.10799889, -0.00300721,
#           -0.08318321],
#          [ 0.10699292,  0.07548596,  0.15142949,  0.17783463,
#           -0.10283263],
#          [-0.11723618, -0.12287579, -0.278727  ,  0.2944783 ,
#            0.32017407],
# ...

# %%
model.layers
