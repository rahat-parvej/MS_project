# %%
import mne
from glob import glob
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import numpy as np
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from concurrent.futures import ThreadPoolExecutor

# %%
prebuild_model = tf.keras.models.load_model("models/gamma_15s_50epoch_32batch.h5")

# %%
global_model = tf.keras.models.clone_model(prebuild_model)
local_model = tf.keras.models.clone_model(prebuild_model)

# %%
global_model.get_weights()
# Out:
# [array([[[ 0.02816325,  0.15715706,  0.02133852,  0.22156346,
#            0.15642938],
#          [ 0.27488345,  0.20100933, -0.2570672 , -0.2093944 ,
#           -0.19707787],
#          [ 0.13406494,  0.01726156, -0.22177693, -0.05798385,
#           -0.22747459],
#          [ 0.09898734, -0.06253535, -0.19950631, -0.21455342,
#           -0.25312325],
#          [-0.13595888, -0.25165692, -0.02322572,  0.08385831,
#           -0.18754375],
#          [-0.12383203,  0.28745425,  0.24576849, -0.01905242,
#           -0.12666263],
#          [ 0.0321548 ,  0.04893631, -0.12766705,  0.06343153,
#           -0.0578707 ],
#          [ 0.13878933, -0.07673205,  0.07820114, -0.18228981,
#            0.21056885],
#          [-0.07793842, -0.07349086, -0.12969851, -0.10168543,
#           -0.02606878],
#          [-0.17187685,  0.27068895, -0.27083066, -0.16891013,
#            0.11887419],
#          [ 0.18114305, -0.2589288 , -0.12340793, -0.14055932,
#            0.14748517],
#          [-0.28244373,  0.1863859 , -0.05265331, -0.01285771,
#           -0.264994  ],
#          [ 0.19315228, -0.18664715, -0.00324988,  0.10774621,
#            0.1341143 ],
#          [-0.27554908, -0.28404525,  0.06950104, -0.13079058,
#           -0.00365642],
#          [-0.10051608, -0.25977936,  0.19207734, -0.16513209,
#            0.07494816],
#          [ 0.15091908,  0.20192483,  0.02624729, -0.26581523,
#            0.21822423],
#          [-0.01412871, -0.24375367,  0.14406866,  0.0946984 ,
#           -0.26586187],
#          [-0.25064394, -0.05453211, -0.23674951,  0.19123554,
#            0.10104886],
#          [ 0.23100603,  0.207329  , -0.14400418,  0.20713499,
#            0.12676504]],
#
#         [[-0.27467665,  0.08648559,  0.25985277,  0.05671987,
#            0.23252726],
#          [-0.28764316, -0.1061902 , -0.15629001, -0.11883448,
#            0.09481266],
#          [ 0.28012973,  0.21273983, -0.27403644, -0.12199715,
#           -0.08854292],
#          [-0.23294808, -0.13968325, -0.19982332, -0.1612219 ,
#           -0.25580853],
#          [ 0.20047262,  0.02597281, -0.11856633, -0.25133088,
#           -0.13129891],
#          [ 0.13520628,  0.26250774, -0.23861144,  0.07958493,
#           -0.27462247],
#          [ 0.00853395,  0.20270395,  0.11223495, -0.12129237,
#           -0.11802502],
#          [ 0.15738639, -0.24459562, -0.05486   ,  0.15143692,
#            0.17352611],
#          [ 0.21110025,  0.21011755, -0.23752615, -0.12541524,
#            0.24391687],
#          [ 0.26252258,  0.2449215 , -0.08009996,  0.06711087,
#            0.04995203],
#          [ 0.01586297,  0.22498083,  0.21898746, -0.18525308,
#            0.01711586],
#          [-0.26867375,  0.05407304,  0.14782888, -0.16809055,
#            0.18920615],
#          [-0.01886976,  0.22588992,  0.03249907, -0.10242055,
#           -0.01006737],
#          [ 0.20963308,  0.08576471, -0.25518712,  0.05775672,
#           -0.05001998],
#          [-0.20420901, -0.0171617 ,  0.16153616,  0.00360101,
#           -0.23275757],
#          [-0.02277264,  0.2709251 , -0.11949664,  0.16709968,
#           -0.01449108],
#          [ 0.17180851, -0.14621086,  0.10680309, -0.00353909,
#            0.10901424],
#          [-0.21814522, -0.1275047 , -0.00422651,  0.00699157,
#            0.07877079],
#          [-0.27043554,  0.11626709,  0.2519645 ,  0.13289973,
#            0.07978234]],
#
#         [[ 0.094331  ,  0.084084  , -0.1326927 , -0.28138444,
#           -0.1025635 ],
#          [-0.0317302 , -0.0886419 ,  0.21419662, -0.2452549 ,
#            0.25943857],
#          [-0.04100879, -0.16044734,  0.12466612, -0.00566509,
#            0.19636971],
#          [ 0.2558233 , -0.03882875,  0.0777199 ,  0.21912944,
#            0.03761342],
#          [ 0.00557899,  0.11465999, -0.01079535,  0.04132751,
#           -0.2464798 ],
#          [ 0.13629895, -0.12505527,  0.22073132,  0.14502871,
#            0.15660992],
#          [-0.0807887 , -0.20734408, -0.1482986 ,  0.09056178,
#            0.14503545],
#          [-0.28408295,  0.25125945, -0.10044375,  0.25541896,
#           -0.06979059],
#          [-0.02947238,  0.05952266, -0.05568439, -0.01488784,
#           -0.17834115],
#          [ 0.2744375 ,  0.08853763,  0.2654965 , -0.02918333,
#           -0.09826501],
#          [-0.1491775 , -0.0203023 ,  0.19282961,  0.22388476,
#           -0.14783582],
#          [-0.03489053,  0.09915444,  0.2455095 , -0.01418585,
#           -0.04332538],
#          [ 0.09984007, -0.274769  ,  0.00906762,  0.2857437 ,
#           -0.12190802],
#          [ 0.07980359,  0.0732854 , -0.22832182, -0.17550051,
#           -0.07972184],
#          [-0.28499323, -0.19190791,  0.267587  , -0.11656   ,
#            0.22140646],
#          [-0.19515634, -0.0751649 ,  0.04219148,  0.2700891 ,
#            0.00849721],
#          [ 0.00862411,  0.05550215,  0.15876153,  0.09342808,
#            0.00532779],
#          [ 0.02581286,  0.09850121,  0.18906707,  0.22953427,
#           -0.12600781],
#          [ 0.15530884,  0.10375103, -0.11979391, -0.0934497 ,
#           -0.05908994]]], dtype=float32),
#  array([0., 0., 0., 0., 0.], dtype=float32),
#  array([1., 1., 1., 1., 1.], dtype=float32),
#  array([0., 0., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., 0., 0.], dtype=float32),
#  array([1., 1., 1., 1., 1.], dtype=float32),
#  array([[[ 0.3336218 , -0.00404733,  0.3221262 ,  0.06915784,
#           -0.01875025],
#          [-0.10854903,  0.40052164, -0.38322234, -0.18168533,
#           -0.19704834],
#          [ 0.2991132 ,  0.2762215 ,  0.04965568,  0.38896018,
#            0.34505475],
#          [ 0.1460405 ,  0.2883597 , -0.19484794,  0.41555363,
#           -0.16989803],
#          [-0.11329463,  0.20567548, -0.39277327, -0.35003975,
#           -0.08882549]],
#
#         [[-0.3169784 ,  0.3024733 ,  0.43181348, -0.18673289,
#            0.36138934],
#          [-0.35636714, -0.4288039 ,  0.00395575, -0.12792379,
#            0.3298229 ],
#          [-0.22254205,  0.31514162,  0.07936794, -0.27692807,
#           -0.24868733],
#          [-0.03240645, -0.23443522,  0.3157968 , -0.14432225,
#            0.11844939],
#          [ 0.18313885,  0.1436196 , -0.16923621, -0.14327115,
#            0.44312465]],
#
#         [[-0.36152434, -0.32880825, -0.26446053, -0.03605685,
#           -0.03821778],
#          [ 0.416902  ,  0.30767268,  0.02727327, -0.18503737,
#           -0.44455   ],
#          [ 0.3203585 , -0.08591732, -0.36715716, -0.43199044,
#            0.43072492],
#          [-0.00850347,  0.36076462,  0.44704503,  0.2775041 ,
#            0.20951772],
#          [-0.08564651, -0.37194568,  0.23263955,  0.00627974,
#           -0.29224592]]], dtype=float32),
#  array([0., 0., 0., 0., 0.], dtype=float32),
#  array([[[ 0.23233706,  0.21144032, -0.24071355,  0.3459891 ,
#            0.31275004],
#          [-0.37801546,  0.298517  ,  0.02673799, -0.0474382 ,
#           -0.15096459],
#          [-0.16622388, -0.3847078 ,  0.32368708, -0.05258271,
#           -0.00868186],
#          [ 0.29224443, -0.09155208,  0.4124987 , -0.13383341,
#           -0.05922687],
#          [-0.31245872, -0.4436294 , -0.1319241 , -0.24015377,
#            0.04680252]],
#
#         [[ 0.00797665,  0.13234144, -0.349474  , -0.01019219,
#            0.28318554],
#          [-0.04131168,  0.03291857,  0.43456966, -0.23370175,
#           -0.00057992],
#          [ 0.1930958 , -0.3175237 , -0.16631377, -0.2596633 ,
#            0.21506172],
#          [ 0.09025925,  0.4153539 , -0.23326768,  0.07961148,
#           -0.19360834],
#          [ 0.05670756,  0.16198373,  0.24452537, -0.1319241 ,
#            0.33173007]],
#
#         [[ 0.20794713, -0.12685156,  0.29802567,  0.24667788,
#           -0.05179805],
#          [ 0.03748998, -0.10706449, -0.44114017, -0.42552316,
#           -0.16582447],
#          [ 0.04378131,  0.05961233,  0.21722609, -0.4470897 ,
#            0.42900455],
#          [-0.007092  ,  0.39329284, -0.06503522, -0.13716957,
#           -0.26777473],
#          [-0.4301129 , -0.09741822, -0.22779946, -0.2713334 ,
#           -0.3462836 ]]], dtype=float32),
#  array([0., 0., 0., 0., 0.], dtype=float32),
#  array([[[ 0.3388741 , -0.13591099,  0.08831894,  0.31226885,
#            0.19923544],
#          [ 0.32813483,  0.38624257,  0.29994088, -0.42609307,
#            0.3611408 ],
#          [-0.17091095, -0.2369655 , -0.11128914,  0.1122269 ,
#           -0.19099647],
#          [-0.26226473, -0.4411728 ,  0.3983814 ,  0.27063823,
#           -0.38168278],
#          [-0.007081  , -0.05026972, -0.07578388, -0.35649234,
#            0.34820348]],
#
#         [[-0.21117955,  0.23481834, -0.08147472, -0.18383017,
#           -0.08553582],
#          [-0.06279749, -0.31053013, -0.2580518 ,  0.10956496,
#            0.42741692],
#          [-0.38679776, -0.21128106,  0.24557358, -0.42293742,
#           -0.36965048],
#          [-0.13360181,  0.30936152, -0.17448169,  0.22843313,
#            0.09522945],
#          [ 0.2759757 , -0.35216916, -0.13756087,  0.37983948,
#           -0.36910382]],
#
#         [[ 0.11957616,  0.35948056, -0.21181108, -0.22085194,
#            0.04870212],
#          [-0.26705396, -0.37277338,  0.2878818 ,  0.43718326,
#            0.3267005 ],
#          [-0.17128307, -0.07803321,  0.14536947, -0.32806635,
#           -0.2507696 ],
#          [-0.01100466, -0.14401239, -0.03833327, -0.13694823,
#           -0.38144854],
#          [ 0.16738564, -0.0372344 ,  0.17240041, -0.05420095,
#            0.21176022]]], dtype=float32),
#  array([0., 0., 0., 0., 0.], dtype=float32),
#  array([[[-0.30181777,  0.03327426, -0.13098484,  0.44711506,
#            0.12657773],
#          [-0.33852488,  0.44586533, -0.25897366, -0.369546  ,
#            0.3657006 ],
#          [ 0.17385644, -0.37117776,  0.0748198 , -0.01279211,
#           -0.19647044],
#          [ 0.42361248, -0.06409106,  0.04199058,  0.0502646 ,
#           -0.31117702],
#          [-0.34832194, -0.25933683,  0.31313527, -0.17730093,
#           -0.13710889]],
#
#         [[ 0.30060256, -0.18500718,  0.06561548,  0.11806244,
#            0.33897847],
#          [ 0.07210064,  0.3461209 ,  0.3097232 ,  0.06563681,
#           -0.3319191 ],
#          [ 0.13456708, -0.28874597, -0.16711503, -0.19576555,
#            0.21111506],
#          [-0.14675763, -0.07249656,  0.33198822, -0.13686207,
#           -0.17408046],
#          [ 0.2773803 , -0.4080299 ,  0.16533655,  0.17170274,
#            0.231655  ]],
#
#         [[-0.32081068,  0.31836742,  0.05469728,  0.43998128,
#           -0.19191143],
#          [-0.00185239,  0.2770694 , -0.44502237,  0.19214565,
#           -0.10341263],
#          [-0.20358941, -0.41289473, -0.05814731,  0.10651785,
#           -0.30024785],
#          [-0.10514751, -0.2603796 ,  0.20471144, -0.3033961 ,
#            0.20816964],
#          [ 0.11668581,  0.05696952, -0.04875341, -0.21874112,
#            0.02995282]]], dtype=float32),
#  array([0., 0., 0., 0., 0.], dtype=float32),
#  array([[-0.7644377 ],
#         [ 0.6606622 ],
#         [-0.6828821 ],
#         [-0.18717694],
#         [ 0.23331451]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
local_model.save_weights("try1_32batch_15s_50epoch/local_model_weights.weights.h5")

# %%
global_model.save_weights("try1_32batch_15s_50epoch/global_model_weights.weights.h5")

# %%
all_files_path=glob('sd_copy/*.edf')
print(len(all_files_path))
# Out:
# 162

# %%
healthy_file_path=[i for i in all_files_path if  'H' in i.split('\\')[1]]
patient_file_path=[i for i in all_files_path if  'M' in i.split('\\')[1]]
print(len(healthy_file_path),len(patient_file_path))
# Out:
# 76 86

# %%
def read_data(file_path):
    raw = mne.io.read_raw_edf(file_path, preload=True)
    raw.pick_types(meg=False, eeg=True, eog=False, ecg=False) # Selecting EEG, EOG and ECG channels
    # Select a specific channel
    channel_to_keep = ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE']  
    # Replace with the name of the channel you want to keep
    raw.pick_channels(channel_to_keep)
    raw.set_eeg_reference()
    raw.filter(l_freq=30,h_freq=100)#1-4=delta, 4-8=theta, 8-12=alpha, 12-30=beta, 30-100=gamma
    epochs=mne.make_fixed_length_epochs(raw,duration=15,overlap=1)
    epochs=epochs.get_data()
    scaler = StandardScaler()
    data = scaler.fit_transform(epochs.reshape(-1,epochs.shape[-1])).reshape(epochs.shape)
    return data #trials,channel,length

# %%
# %%capture
control_epochs_array=[read_data(subject) for subject in healthy_file_path]
patients_epochs_array=[read_data(subject) for subject in patient_file_path]
control_epochs_labels=[len(i)*[0] for i in control_epochs_array]
patients_epochs_labels=[len(i)*[1] for i in patients_epochs_array]
data_list=control_epochs_array+patients_epochs_array
label_list=control_epochs_labels+patients_epochs_labels
groups_list=[[i]*len(j) for i, j in enumerate(data_list)]
data_array=np.vstack(data_list)
label_array=np.hstack(label_list)
group_array=np.hstack(groups_list)

# %%
print(data_array.shape,label_array.shape)
# Out:
# (4638, 19, 3840) (4638,)

# %%
data_array=np.moveaxis(data_array,1,2)

# %%
X=data_array
y=label_array

# %%
# y=tf.keras.utils.to_categorical(y)

# %%
y.shape
# Out:
# (4638,)

# %%
num_clients=3
clients_X, clients_y = np.array_split(X, num_clients), np.array_split(y, num_clients)
clients_group_array = np.array_split(group_array, num_clients)

# %%
def train_client_model(model, data_X, data_y, group_data):
    data_X=data_X
    data_y=data_y
    Group_data= group_data
    gkf=GroupKFold(n_splits=2)
    for train_index, val_index in gkf.split(data_X, data_y, groups=group_data):
        train_features,train_labels=data_X[train_index],data_y[train_index]
        val_features,val_labels=data_X[val_index],data_y[val_index]
        scaler=StandardScaler()
        train_features = scaler.fit_transform(train_features.reshape(-1, train_features.shape[-1])).reshape(train_features.shape)
        val_features = scaler.transform(val_features.reshape(-1, val_features.shape[-1])).reshape(val_features.shape)
        # model=cnnmodel()
        model.fit(train_features,train_labels,epochs=5,batch_size=25,validation_data=(val_features,val_labels))
        evaluation_results = model.evaluate(val_features,val_labels)

    return model

# %%
# Clone the global model for each client

for client_id in range(num_clients):
    globals()['client_model%s' % client_id] = tf.keras.models.clone_model(local_model)
    globals()['client_model%s' % client_id].compile('adam',loss='binary_crossentropy',metrics=['Accuracy', 'Precision', 'Recall','AUC'])

# %%
with ThreadPoolExecutor() as executor:
    for i in range(num_clients):
        globals()['future%s' % i] = executor.submit(train_client_model, globals()['client_model%s' % i], clients_X[i], clients_y[i],clients_group_array[i])
# Out:
# Epoch 1/5
# Epoch 1/5
# Epoch 1/5
# 31/31 [==============================] - 23s 332ms/step - loss: 0.7940 - Accuracy: 0.0959 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.6451 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# Epoch 2/5
# 31/31 [==============================] - 23s 366ms/step - loss: 0.6756 - Accuracy: 0.5925 - precision: 0.5925 - recall: 1.0000 - auc: 0.5316 - val_loss: 0.6500 - val_Accuracy: 0.6119 - val_precision: 0.6119 - val_recall: 1.0000 - val_auc: 0.9364
# Epoch 2/5
# 31/31 [==============================] - 24s 329ms/step - loss: 0.4698 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 0.3233 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
# Epoch 2/5
# 31/31 [==============================] - 7s 225ms/step - loss: 0.6053 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.5105 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# Epoch 3/5
# 31/31 [==============================] - 7s 217ms/step - loss: 0.6149 - Accuracy: 0.5951 - precision: 0.5940 - recall: 1.0000 - auc: 0.8358 - val_loss: 0.5585 - val_Accuracy: 0.7322 - val_precision: 0.6956 - val_recall: 1.0000 - val_auc: 0.9498
#  2/31 [>.............................] - ETA: 3s - loss: 0.5057 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00Epoch 3/5
# 31/31 [==============================] - 7s 219ms/step - loss: 0.1170 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 0.0285 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
#  2/31 [>.............................] - ETA: 4s - loss: 0.4847 - Accuracy: 0.8600 - precision: 0.8409 - recall: 1.0000 - auc: 0.9168Epoch 3/5
# 31/31 [==============================] - 6s 201ms/step - loss: 0.3487 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.1582 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# Epoch 4/5
# 31/31 [==============================] - 6s 202ms/step - loss: 0.4802 - Accuracy: 0.7982 - precision: 0.7459 - recall: 1.0000 - auc: 0.9328 - val_loss: 0.3959 - val_Accuracy: 0.9043 - val_precision: 0.8647 - val_recall: 1.0000 - val_auc: 0.9526
#  2/31 [>.............................] - ETA: 3s - loss: 0.1481 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00Epoch 4/5
# 31/31 [==============================] - 6s 209ms/step - loss: 0.0100 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 0.0064 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
# Epoch 4/5
# 31/31 [==============================] - 7s 226ms/step - loss: 0.0633 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.0182 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# Epoch 5/5
# 31/31 [==============================] - 7s 221ms/step - loss: 0.2769 - Accuracy: 0.8991 - precision: 0.8558 - recall: 0.9978 - auc: 0.9753 - val_loss: 0.2571 - val_Accuracy: 0.9392 - val_precision: 0.9209 - val_recall: 0.9852 - val_auc: 0.9545
# Epoch 5/5
# 31/31 [==============================] - 7s 225ms/step - loss: 0.0029 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 0.0037 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
#  4/31 [==>...........................] - ETA: 5s - loss: 0.2326 - Accuracy: 0.9100 - precision: 0.8657 - recall: 1.0000 - auc: 0.9762Epoch 5/5
# 31/31 [==============================] - 7s 223ms/step - loss: 0.0096 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.0062 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# 31/31 [==============================] - 7s 218ms/step - loss: 0.1769 - Accuracy: 0.9366 - precision: 0.9098 - recall: 0.9913 - auc: 0.9857 - val_loss: 0.2298 - val_Accuracy: 0.9314 - val_precision: 0.9134 - val_recall: 0.9810 - val_auc: 0.9494
# 31/31 [==============================] - 6s 201ms/step - loss: 0.0016 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 0.0026 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
# 25/25 [==============================] - 2s 65ms/step - loss: 0.0062 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00
# 25/25 [==============================] - 2s 66ms/step - loss: 0.2298 - Accuracy: 0.9314 - precision: 0.9134 - recall: 0.9810 - auc: 0.9494
# 25/25 [==============================] - 3s 37ms/step - loss: 0.0026 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00
# Epoch 1/5
# Epoch 1/5
# 31/31 [==============================] - 7s 220ms/step - loss: 0.2080 - Accuracy: 0.9353 - precision: 0.9188 - recall: 0.9810 - auc: 0.9664 - val_loss: 0.1526 - val_Accuracy: 0.9470 - val_precision: 0.9707 - val_recall: 0.9389 - val_auc: 0.9877
# 31/31 [==============================] - 7s 221ms/step - loss: 0.0042 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.0023 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# Epoch 2/5
# Epoch 2/5
#  3/31 [=>............................] - ETA: 4s - loss: 0.0032 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00Epoch 1/5
# 31/31 [==============================] - 6s 203ms/step - loss: 0.0025 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.0015 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# Epoch 3/5
# 31/31 [==============================] - 6s 208ms/step - loss: 0.1121 - Accuracy: 0.9754 - precision: 0.9652 - recall: 0.9958 - auc: 0.9976 - val_loss: 0.1731 - val_Accuracy: 0.9185 - val_precision: 0.9341 - val_recall: 0.9279 - val_auc: 0.9784
# Epoch 3/5
# 31/31 [==============================] - 9s 306ms/step - loss: 0.0015 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 9.6015e-04 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
# Epoch 2/5
# 31/31 [==============================] - 6s 201ms/step - loss: 0.0701 - Accuracy: 0.9858 - precision: 0.9853 - recall: 0.9915 - auc: 0.9995 - val_loss: 0.1831 - val_Accuracy: 0.9237 - val_precision: 0.9200 - val_recall: 0.9541 - val_auc: 0.9751
# Epoch 4/5
# 31/31 [==============================] - 6s 209ms/step - loss: 0.0017 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.0011 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# Epoch 4/5
# 31/31 [==============================] - 6s 207ms/step - loss: 0.0010 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 6.6033e-04 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
# Epoch 3/5
# 31/31 [==============================] - 6s 206ms/step - loss: 0.0012 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 8.0759e-04 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# Epoch 5/5
# 31/31 [==============================] - 6s 208ms/step - loss: 0.0367 - Accuracy: 0.9974 - precision: 0.9958 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2065 - val_Accuracy: 0.9094 - val_precision: 0.9273 - val_recall: 0.9192 - val_auc: 0.9744
# Epoch 5/5
# 31/31 [==============================] - 6s 210ms/step - loss: 7.2197e-04 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 4.8348e-04 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
# 25/31 [=======================>......] - ETA: 0s - loss: 0.0010 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00Epoch 4/5
# 31/31 [==============================] - 6s 210ms/step - loss: 9.4932e-04 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 6.3149e-04 - val_Accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.0000e+00
# 31/31 [==============================] - 7s 215ms/step - loss: 0.0365 - Accuracy: 0.9935 - precision: 0.9937 - recall: 0.9958 - auc: 0.9999 - val_loss: 0.2077 - val_Accuracy: 0.9237 - val_precision: 0.9200 - val_recall: 0.9541 - val_auc: 0.9745
# 31/31 [==============================] - 6s 187ms/step - loss: 5.5047e-04 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 3.7770e-04 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
# Epoch 5/5
# 25/25 [==============================] - 2s 70ms/step - loss: 0.2077 - Accuracy: 0.9237 - precision: 0.9200 - recall: 0.9541 - auc: 0.9745 0.0000e+0
# 25/25 [==============================] - 2s 79ms/step - loss: 6.3149e-04 - Accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00
# 31/31 [==============================] - 4s 122ms/step - loss: 4.0448e-04 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00 - val_loss: 3.0414e-04 - val_Accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 0.0000e+00
# 25/25 [==============================] - 1s 30ms/step - loss: 3.0414e-04 - Accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.0000e+00

# %%
for j in range(num_clients):
    globals()['client_model%s' % j] = globals()['future%s' % j].result()

# %%
client_model2.get_weights()
# Out:
# [array([[[ 0.23915273,  0.09087033,  0.10885888, -0.1566909 ,
#           -0.1552707 ],
#          [-0.0223843 ,  0.08566833, -0.01153228,  0.06614044,
#           -0.2022529 ],
#          [ 0.05676519,  0.09741896,  0.306782  ,  0.05215501,
#            0.03201086],
#          [-0.20256838, -0.23985922, -0.07778507, -0.28046748,
#           -0.06665123],
#          [ 0.108548  , -0.32049042,  0.06765447, -0.2419018 ,
#           -0.2133915 ],
#          [ 0.22083935, -0.16632928, -0.09049753, -0.15297529,
#            0.27921727],
#          [ 0.05169789, -0.09425769,  0.13482223, -0.06618448,
#            0.08597369],
#          [ 0.09054499,  0.03898213, -0.16376656,  0.10294817,
#           -0.16684765],
#          [-0.29140592, -0.20506375, -0.21247613, -0.05688139,
#            0.16908535],
#          [-0.30069202, -0.11855864, -0.03729041,  0.13993913,
#           -0.07008845],
#          [ 0.10670479,  0.04547297,  0.25404945,  0.04185706,
#            0.24598776],
#          [-0.21886027,  0.33465734, -0.12155315,  0.3002488 ,
#           -0.02304383],
#          [ 0.34483054, -0.22982447,  0.11877964,  0.21188201,
#           -0.04478004],
#          [-0.15379323, -0.18208693,  0.13283592,  0.17326836,
#           -0.18480271],
#          [ 0.14354365,  0.20362495, -0.09260079, -0.17609341,
#            0.2995394 ],
#          [-0.0033323 ,  0.00081441, -0.04183197, -0.16558324,
#            0.27372348],
#          [ 0.12284857, -0.25125104,  0.2268509 , -0.17987587,
#           -0.19083968],
#          [-0.20788592, -0.12814578,  0.08204149,  0.11297201,
#           -0.28039956],
#          [ 0.2151854 ,  0.16220868,  0.00244744, -0.13762128,
#            0.2058895 ]],
#
#         [[-0.15727474,  0.31584215,  0.29551876,  0.11664854,
#           -0.22258355],
#          [ 0.00651777,  0.3300758 ,  0.06087051,  0.1076218 ,
#           -0.21168464],
#          [ 0.14959787,  0.13206355, -0.09519739,  0.01281029,
#           -0.23076576],
#          [-0.12292346, -0.06834807, -0.24793823,  0.22243756,
#           -0.04435082],
#          [-0.21768484,  0.01168721,  0.10897736, -0.0533604 ,
#            0.05978352],
#          [-0.04572269, -0.04166825,  0.14543988, -0.03526964,
#            0.07870939],
#          [ 0.27180177,  0.06917451,  0.22642848,  0.03677513,
#           -0.24736193],
#          [ 0.23739092,  0.07933839,  0.25355464, -0.2766128 ,
#           -0.07322779],
#          [-0.26370114,  0.00254749, -0.1668264 , -0.18849905,
#           -0.16913027],
#          [-0.18626207, -0.17348056, -0.08176643,  0.11290961,
#            0.25711107],
#          [-0.13331996,  0.22163327, -0.00607061,  0.23784722,
#            0.34807837],
#          [-0.27750102, -0.19539228, -0.0848911 ,  0.17858036,
#            0.16878594],
#          [-0.21984641, -0.14005753,  0.11790574, -0.06533296,
#           -0.26598436],
#          [-0.04407725, -0.05537394,  0.22878844, -0.32390794,
#            0.11937691],
#          [-0.26851317,  0.02666266, -0.0686297 , -0.08066617,
#           -0.10367959],
#          [-0.35656044,  0.29717112, -0.12448674, -0.09437392,
#            0.07243813],
#          [ 0.12033778,  0.05970553, -0.0055922 , -0.1717808 ,
#           -0.03183426],
#          [-0.07154835,  0.06363987,  0.12006104,  0.01994422,
#            0.14261335],
#          [-0.16058639,  0.03714831, -0.09118462,  0.0940082 ,
#           -0.29406857]],
#
#         [[ 0.08988971, -0.0610842 ,  0.03127518,  0.04357134,
#           -0.00232003],
#          [ 0.15353233, -0.14327   , -0.21314594,  0.09822717,
#            0.05385606],
#          [-0.0130163 ,  0.15321304,  0.11454856, -0.1057081 ,
#            0.09439036],
#          [-0.05983967, -0.29305694,  0.24509704, -0.10332577,
#            0.01603182],
#          [ 0.01029553, -0.12097025, -0.09970276, -0.13311356,
#           -0.03733776],
#          [ 0.1589948 , -0.05330883,  0.02170165, -0.19241105,
#           -0.26169753],
#          [ 0.12131938, -0.17312941,  0.10744932,  0.01302399,
#            0.07287103],
#          [-0.19018243, -0.04376076,  0.26259676, -0.22312233,
#            0.08136167],
#          [-0.16686672,  0.08265108,  0.1871916 , -0.02706587,
#           -0.10721064],
#          [ 0.06133434,  0.02442021,  0.18396786, -0.23981759,
#           -0.00036171],
#          [-0.3433187 ,  0.01530205, -0.17537393,  0.13854025,
#           -0.18638587],
#          [-0.11498003,  0.02790629,  0.04778717, -0.30051562,
#            0.280644  ],
#          [ 0.32088622, -0.2383523 ,  0.27424094, -0.23727952,
#           -0.2526147 ],
#          [ 0.2327301 , -0.19829303,  0.1629398 , -0.13772354,
#           -0.10754484],
#          [ 0.10963333,  0.24705063, -0.01230642,  0.0745841 ,
#           -0.10404681],
#          [ 0.05968421,  0.05590586, -0.02051625, -0.02463193,
#           -0.10470084],
#          [-0.10234527, -0.20170338, -0.2100722 ,  0.1939452 ,
#            0.05821369],
#          [-0.02224543,  0.06396505,  0.0120204 , -0.09400222,
#           -0.05623173],
#          [ 0.0122116 ,  0.0546069 ,  0.00957799, -0.06166691,
#            0.01005904]]], dtype=float32),
#  array([-0.00012619, -0.00049933,  0.00010564, -0.00024295, -0.00121119],
#        dtype=float32),
#  array([1.097229 , 1.090571 , 1.0888795, 1.0817597, 0.9158356],
#        dtype=float32),
#  array([ 0.10740308,  0.1079959 ,  0.10190119,  0.09441689, -0.08308479],
#        dtype=float32),
#  array([-1.3000160e-04, -5.1526062e-04,  9.4847812e-05, -2.3864329e-04,
#         -9.9199754e-04], dtype=float32),
#  array([1.757993 , 2.6153884, 1.3816172, 1.538322 , 1.9693279],
#        dtype=float32),
#  array([[[-0.2107268 ,  0.00349336, -0.00475047,  0.13840811,
#            0.14194798],
#          [ 0.22956268,  0.26769355,  0.1675583 , -0.08303555,
#            0.28917664],
#          [-0.10946943, -0.22037101,  0.37005275,  0.38642165,
#           -0.33063662],
#          [ 0.11600571,  0.38150597,  0.11278906, -0.1301743 ,
#           -0.0670212 ],
#          [-0.22639528, -0.24612242,  0.05909212,  0.02547374,
#           -0.21413386]],
#
#         [[ 0.22094283,  0.23663588, -0.41080284,  0.27616838,
#           -0.22518215],
#          [ 0.25912997,  0.11517166, -0.17250794,  0.12295862,
#           -0.43937266],
#          [ 0.30755246,  0.4344592 ,  0.29407433,  0.22213309,
#           -0.18276252],
#          [ 0.21718282,  0.48709285, -0.2314301 ,  0.41006842,
#           -0.0606248 ],
#          [ 0.30012468, -0.13861066,  0.32396594, -0.17889205,
#           -0.07036364]],
#
#         [[-0.28172094,  0.13248198, -0.4924091 , -0.1361841 ,
#           -0.20434278],
#          [ 0.10234709,  0.07181924,  0.15145381,  0.43008634,
#            0.33323234],
#          [ 0.43452218,  0.10310134,  0.2808519 , -0.01037903,
#           -0.48551837],
#          [-0.28627887, -0.2859773 , -0.4702989 ,  0.21325444,
#           -0.46006805],
#          [-0.36406434, -0.31027508,  0.158664  ,  0.24318403,
#            0.05562078]]], dtype=float32),
#  array([ 0.08588699,  0.09929109, -0.05909031,  0.07946104, -0.08105516],
#        dtype=float32),
#  array([[[ 3.5367829e-01,  4.4043431e-01, -1.9143613e-01, -2.7482429e-01,
#           -5.1569879e-01],
#          [-9.5648006e-02,  3.4346277e-01,  4.0419528e-01,  4.7265467e-01,
#           -1.6202050e-01],
#          [-8.1360020e-02,  4.7372105e-03,  4.2345548e-01,  2.8397763e-01,
#           -4.6874961e-01],
#          [ 3.5728750e-01, -1.6245160e-01, -4.6678159e-02,  2.4200152e-01,
#           -4.4502318e-01],
#          [ 5.4394845e-02, -1.3194187e-02, -4.9097309e-01, -2.7059421e-01,
#            3.0575797e-01]],
#
#         [[ 1.1563349e-01,  2.8815636e-01, -8.9384139e-02,  4.3351356e-02,
#           -4.9430677e-01],
#          [-2.0423518e-01,  5.1691854e-01,  4.9476612e-01,  9.1082267e-02,
#           -2.4239217e-01],
#          [-1.7912571e-01,  2.1781327e-01, -5.7604771e-02, -1.6683720e-01,
#            2.1564319e-04],
#          [-2.7508184e-01, -2.9697484e-01,  6.7168392e-02, -2.9699335e-01,
#           -4.6988800e-01],
#          [ 2.1825203e-01,  2.9295957e-01,  7.2683685e-02, -2.2512975e-01,
#            3.1501290e-01]],
#
#         [[-2.3056731e-01,  3.9303222e-01, -4.6057170e-03, -7.3906243e-02,
#            2.4422157e-01],
#          [-1.5560934e-01, -2.9239172e-01, -1.2386732e-01,  5.1908225e-01,
#            3.0306131e-01],
#          [-3.0942115e-01, -9.6696682e-02, -9.2429355e-02, -2.4948062e-01,
#            4.0722344e-02],
#          [ 2.8027403e-01,  4.5761636e-01,  1.4159109e-01,  3.5812646e-01,
#            3.5969523e-01],
#          [-1.8904515e-01, -8.9715056e-02, -3.4335998e-01, -4.3493325e-01,
#            2.2377986e-01]]], dtype=float32),
#  array([ 0.06991786,  0.08336911,  0.07961012,  0.08153164, -0.06717163],
#        dtype=float32),
#  array([[[ 0.19147842, -0.24151286, -0.17751427,  0.50232536,
#            0.04123561],
#          [-0.21917915, -0.40866515, -0.13240135,  0.3157475 ,
#            0.4324081 ],
#          [-0.0813823 ,  0.18483569,  0.0070617 ,  0.18145253,
#            0.46086967],
#          [ 0.09949737,  0.3231347 , -0.04577625,  0.50868577,
#            0.49197474],
#          [ 0.34596786,  0.29862338, -0.02432212, -0.51553077,
#           -0.3066143 ]],
#
#         [[ 0.33188477, -0.47340563, -0.47150913,  0.06655005,
#            0.33750027],
#          [-0.08123612, -0.00591025, -0.07950164, -0.22160172,
#            0.48999766],
#          [ 0.16466057, -0.29791567,  0.24966049, -0.17354648,
#            0.23858388],
#          [-0.06188593,  0.3290794 , -0.23557712,  0.4503491 ,
#           -0.05421846],
#          [-0.16757515,  0.45030028, -0.00191166,  0.02739699,
#           -0.23757815]],
#
#         [[-0.21199691, -0.12785837, -0.51506156, -0.31461492,
#            0.470208  ],
#          [-0.3942943 ,  0.1015419 , -0.5040081 , -0.05714229,
#           -0.127093  ],
#          [-0.3649289 ,  0.24206056, -0.5539856 , -0.07723594,
#            0.08443969],
#          [-0.2478072 ,  0.43119487, -0.00992222, -0.05267873,
#            0.03645653],
#          [ 0.05028476,  0.4660602 ,  0.4677995 , -0.41706032,
#           -0.1058208 ]]], dtype=float32),
#  array([ 0.01732307, -0.04413353, -0.06130846,  0.06719474,  0.07057976],
#        dtype=float32),
#  array([[[ 1.11503825e-01,  2.29008585e-01, -4.75055480e-04,
#           -4.15465906e-02,  1.17984273e-01],
#          [-1.13758333e-01,  2.16258466e-01, -1.01396680e-01,
#           -2.40876988e-01,  1.79007977e-01],
#          [-4.04120177e-01, -4.71272439e-01,  1.47432402e-01,
#           -4.96565521e-01, -4.86404300e-02],
#          [-3.05624723e-01, -4.43741530e-02,  5.29161930e-01,
#            3.07655651e-02,  4.78280395e-01],
#          [-1.98586658e-01, -2.99617410e-01,  4.96701151e-01,
#            3.26909840e-01, -2.75077403e-01]],
#
#         [[ 1.95916414e-01, -4.39724982e-01, -4.36958134e-01,
#           -4.29091752e-01, -4.99555111e-01],
#          [ 3.41100067e-01,  4.54738885e-01,  1.91825941e-01,
#           -3.29282314e-01,  1.94704950e-01],
#          [ 1.57693222e-01,  2.10377991e-01,  3.30178022e-01,
#           -3.77690554e-01,  1.06642179e-01],
#          [ 4.10403758e-01,  2.52623223e-02, -3.08447421e-01,
#            2.26506829e-01,  4.07174438e-01],
#          [ 4.08994849e-04, -1.27732975e-03,  4.35388163e-02,
#            3.96671984e-03,  2.43223131e-01]],
#
#         [[-4.42157507e-01,  2.28368312e-01,  2.55759984e-01,
#           -1.97241887e-01, -2.16550365e-01],
#          [ 4.79564220e-01,  4.28246588e-01, -3.70271355e-01,
#           -4.30567227e-02, -1.86093330e-01],
#          [-4.29563731e-01, -2.67221361e-01, -6.11318834e-02,
#           -6.54632226e-02, -1.26914442e-01],
#          [ 2.32250869e-01,  4.08331126e-01,  3.05596471e-01,
#            3.93311262e-01, -2.64260411e-01],
#          [ 1.81800246e-01,  1.80984765e-01,  2.84865290e-01,
#            3.20595801e-01, -1.90781251e-01]]], dtype=float32),
#  array([0.05509222, 0.06483912, 0.05581528, 0.06142315, 0.05653974],
#        dtype=float32),
#  array([[0.81099147],
#         [0.09829687],
#         [0.90646315],
#         [0.5158745 ],
#         [0.28554145]], dtype=float32),
#  array([0.05159278], dtype=float32)]
