# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D,BatchNormalization,LeakyReLU,MaxPool1D,\
GlobalAveragePooling1D,Dense,Dropout,AveragePooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session

# %%
def cnnmodel():
    clear_session()
    model=Sequential()
    model.add(Conv1D(filters=5,kernel_size=3,strides=1,input_shape=(3840,20)))#1
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPool1D(pool_size=2,strides=2))#2
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#3
    model.add(LeakyReLU())
    model.add(MaxPool1D(pool_size=2,strides=2))#4
    model.add(Dropout(0.5))
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#5
    model.add(LeakyReLU())
    model.add(AveragePooling1D(pool_size=2,strides=2))#6
    model.add(Dropout(0.5))
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#7
    model.add(LeakyReLU())
    model.add(AveragePooling1D(pool_size=2,strides=2))#8
    model.add(Conv1D(filters=5,kernel_size=3,strides=1))#9
    model.add(LeakyReLU())
    model.add(GlobalAveragePooling1D())#10
    model.add(Dense(1,activation='sigmoid'))#11
    
    model.compile('adam',loss='binary_crossentropy',metrics=['Accuracy', 'Precision', 'Recall','AUC'])
    return model

prebuild_model=cnnmodel()
prebuild_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 3838, 5)           305
#
#  batch_normalization (Batch  (None, 3838, 5)           20
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 3838, 5)           0
#
#  max_pooling1d (MaxPooling1  (None, 1919, 5)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 1917, 5)           80
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 1917, 5)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 958, 5)            0
#  g1D)
#
#  dropout (Dropout)           (None, 958, 5)            0
#
#  conv1d_2 (Conv1D)           (None, 956, 5)            80
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 956, 5)            0
#
#  average_pooling1d (Average  (None, 478, 5)            0
#  Pooling1D)
#
#  dropout_1 (Dropout)         (None, 478, 5)            0
#
#  conv1d_3 (Conv1D)           (None, 476, 5)            80
#
# ...

# %%
prebuild_model.save("model.h5")

# %%
prebuild_model.get_weights()
# Out:
# [array([[[ 0.19216695, -0.22146605, -0.24416229, -0.10128933,
#           -0.14877516],
#          [-0.18260303, -0.17936397,  0.17977837,  0.26067483,
#           -0.11431725],
#          [-0.18382916,  0.24683464,  0.23101747,  0.12158611,
#           -0.05771825],
#          [-0.28517714, -0.19295475,  0.07790098, -0.07477121,
#           -0.14584257],
#          [-0.13476132,  0.07986197,  0.23367852,  0.23592085,
#            0.17709258],
#          [-0.1692105 ,  0.19293326, -0.26138967,  0.27801985,
#           -0.15096442],
#          [-0.26422295, -0.23213704,  0.08296144, -0.20902571,
#           -0.11286098],
#          [-0.02700445,  0.23858571, -0.04006691, -0.06593415,
#           -0.06282558],
#          [-0.21004921,  0.10062158, -0.18836457,  0.17679775,
#            0.17066127],
#          [ 0.06442425, -0.02800757, -0.15156156,  0.01067778,
#            0.22424382],
#          [ 0.03683329, -0.1723    ,  0.05768123, -0.21998967,
#            0.16385826],
# ...

# %%
# from tensorflow.keras.utils import plot_model
# plot_model(prebuild_model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
